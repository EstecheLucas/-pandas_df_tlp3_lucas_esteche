# %% [markdown]
# # Actividad - Trabajando con DataFrames de Pandas.
# ## Criterios de evaluación.
#
# * Se deben utilizar nombres de variables descriptivos y claros (Utilizar la nomeclatura correspondiente para los nombres de variables).
# * Comentarios claros y concisos que expliquen el propósito de cada sección del código.
# * Utilizar mensajes de commit **descriptivos**. (Puedes utilizar la extension CONVENTIONAL COMMIT de VS-CODE).
# * Entrega en tiempo y forma.
# * Todo el código desarrollado debe ser subido a un repositorio en GitHub (el nombre del repositorio de seguir la siguiente estructura: pandas_df_tlp3_nombre_apellido).
# * Para resolver las actividades se debe insertar casillas de codigo entre cada actividad del cuaderno de Jupyter
# * Deben trabajar con el datasets adjunto a la actividad
#
# ### ¡Importante!
# **El incumplimiento de los criterios de evaluación restará puntos en la nota final del práctico!**

# %%
import pandas as pd
import sqlite3

# Aquí agrega la conexión a la base de datos
conn = sqlite3.connect('Salaries.sqlite')

# Crea el DataFrame con los datos del dataset
df = pd.read_sql_query("SELECT * FROM salaries", conn)

# muestr las primeras filas para verificar
print(df.head())

# Cirra la conexión
conn.close()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25     None  567595.43         567595.43
# 1  155966.02   245131.88  137811.38     None  538909.28         538909.28
# 2  212739.13   106088.18    16452.6     None  335279.91         335279.91
# 3    77916.0    56120.71   198306.9     None  332343.61         332343.61
# 4   134401.6      9737.0  182234.59     None  326373.19         326373.19
#
#    Year Notes         Agency Status
# 0  2011  None  San Francisco   None
# ...

# %% [markdown]
# 1. **Top 10 empleados con mayor salario total (incluyendo beneficios)**
# Extrae e imprime un top 10 de expleados con mayor salario incluyendo los beneficios

# %%
#todo
# ordenamos el DataFrame por la columna 'TotalpayBenefits' de mayor a menor
top10 = df.sort_values(by='TotalPayBenefits', ascending=False).head(10)

# Mostramos solo las columnas que nos interesan: nombre del empleado, cargo y salrio total con beneficios
print(top10[['EmployeeName', 'JobTitle', 'TotalPayBenefits']])
# Out:
#                 EmployeeName                                        JobTitle  \
# 0             NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1               GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 110531           David Shinn                                  Deputy Chief 3
# 110532            Amy P Hart                               Asst Med Examiner
# 110533  William J Coaker Jr.                        Chief Investment Officer
# 72925         Gregory P Suhr                                 Chief of Police
# 72926   Joanne M Hayes-White                          Chief, Fire Department
# 110534        Gregory P Suhr                                 Chief of Police
# 110535  Joanne M Hayes-White                          Chief, Fire Department
# 110536       Ellen G Moffatt                               Asst Med Examiner
#
#         TotalPayBenefits
# 0              567595.43
# 1              538909.28
# 110531         510732.68
# ...

# %% [markdown]
# 2. **Filtrar empleados con más de 50,000 en horas extra, la columna a tratar es: (OvertimePay)**

# %%
# Asegurarnos de que la columna Overtimepay sea numérica
df['OvertimePay'] = pd.to_numeric(df['OvertimePay'], errors='coerce')

# Filtrar los empleados que tienen más de 50000 en horas extra
filtro_overtime = df[df['OvertimePay'] > 50000]


print(filtro_overtime[['EmployeeName', 'JobTitle', 'OvertimePay']])
# Out:
#               EmployeeName                              JobTitle  OvertimePay
# 1             GARY JIMENEZ       CAPTAIN III (POLICE DEPARTMENT)    245131.88
# 2           ALBERT PARDINI       CAPTAIN III (POLICE DEPARTMENT)    106088.18
# 3        CHRISTOPHER CHONG  WIRE ROPE CABLE MAINTENANCE MECHANIC     56120.71
# 6                ALSON LEE    BATTALION CHIEF, (FIRE DEPARTMENT)     89062.90
# 8           MICHAEL MORRIS    BATTALION CHIEF, (FIRE DEPARTMENT)     86362.68
# ...                    ...                                   ...          ...
# 118288    Francisco A Arce                      Transit Operator     51625.42
# 118342    Felix Pagatpatan                      Transit Operator     52550.53
# 119450         Bobby Jones              Track Maintenance Worker     50265.23
# 119607       Hung V Nguyen             Diagnostic Imaging Tech I     74935.96
# 120204  Girma-Worku Zeleke               Parking Control Officer     54738.36
#
# [2165 rows x 3 columns]

# %% [markdown]
# 3. **Contar cuántos empleados únicos hay por año**

# %%
#todo
# Agrupamos los datos por la columna 'Year' y contamos los empleados únicos por cada año
empleados_por_anno = df.groupby('Year')['EmployeeName'].nunique()

# Mostramos el número de empleados únicos por cada año
print(empleados_por_anno)
# Out:
# Year
# 2011    33878
# 2012    34349
# 2013    36150
# 2014    36684
# Name: EmployeeName, dtype: int64

# %% [markdown]
# 4. **Ver cuántos cargos únicos (JobTitle) existen y los 5 más comunes**

# %%
#todo
# Contamos cuántos cargos únicos (JobTitle) existen
cargos_unicos = df['JobTitle'].nunique()

# Mostramos cuántos cargos únicos hay
print(f"Cantidad de cargos únicos: {cargos_unicos}")

# Obtenemos los 5 cargos más comnes
top_5_cargos = df['JobTitle'].value_counts().head(5)

# Mostramos los 5 cargos más comunes
print("Los 5 cargos más comunes son:")
print(top_5_cargos)
# Out:
# Cantidad de cargos únicos: 2159
# Los 5 cargos más comunes son:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %% [markdown]
# 5. **Mostrar el salario total (TotalPay) promedio por año**

# %%
#todo
# Agrupamos los datos por la columna 'Year' y calculamos el salario total promedio por cada año
salario_promedio_anno = df.groupby('Year')['TotalPay'].mean()

# Mostramos el salario total promedio por año
print(salario_promedio_anno)
# Out:
# Year
# 2011    71744.103871
# 2012    74113.262265
# 2013    77611.443142
# 2014    75463.918140
# Name: TotalPay, dtype: float64

# %% [markdown]
# 6. **Exporta todos los datos a un CSV y muestra los ultimos 10 valores**

# %%
#todo
# Exportamos todo el DataFrame a un archivo CSV
df.to_csv('empleados_salaries.csv', index=False)

# Mostramos los últimos 10 valores del DataFrame
print(df.tail(10))
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#         OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...
